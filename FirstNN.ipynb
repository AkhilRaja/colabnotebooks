# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhilRaja/colabnotebooks/blob/master/FirstNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First Neural network to extend a line and train an NN to fit a line.
#Tensorflow 2.x

# %%
#import statements
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#Dummy data   
X = np.array([-1,0,1,3,4,5,7])
Y = np.array([-1,-1,1,5,7,9,13])

# %%
#Create and train the model 
model = tf.keras.Sequential([keras.layers.Dense(1,input_shape=[1])])
model.compile(optimizer='sgd',loss='mean_squared_error')
model.fit(X,Y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 55.8149
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 27.6943
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 13.8788
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0904
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7538
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1129
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3049
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9062
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7085
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6096
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5593
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5328
# ...

# %%
#Use the model to predict the values
print(model.predict([10.0]))
# Out:
# [[18.185213]]
